# %% [markdown]
# # OpenML in Python
# Joaquin Vanschoren @joavanschoren

# %% [markdown]
# ## Authentication
# * Create an OpenML account on http://www.openml.org
# * Go to your OpenML account, click 'Account Settings', and then 'API authentication'.
# <center><img src="images/openml_login.png" width="800"></center>
# * Create a little file to store the API key locally: ~/.openml/config

# %%
apikey=FILL_IN_API_KEY
cachedir=FILL_IN_CACHE_DIR

# %% [markdown]
# # Data

# %% [markdown]
# ## List ALL the datasets

# %%
from openml import datasets, tasks, runs
import numpy as np
import pandas as pd
import os

# %%
from openml import datasets, tasks, runs
import numpy as np
import pandas as pd
import os

datalist = datasets.list_datasets()

data = pd.DataFrame(datalist).transpose()
print("First 10 of %s datasets..." % len(datalist))
print(data[:10][['did','name','NumberOfInstances','NumberOfFeatures']])
# Out:
# First 10 of 19492 datasets...
#    did             name NumberOfInstances NumberOfFeatures
# 1    1           anneal               898               39
# 2    2           anneal               898               39
# 3    3         kr-vs-kp              3196               37
# 4    4            labor                57               17
# 5    5       arrhythmia               452              280
# 6    6           letter             20000               17
# 7    7        audiology               226               70
# 8    8  liver-disorders               345                7
# 9    9            autos               205               26
# 10  10            lymph               148               19

# %% [markdown]
# Download a specific dataset. This is done based on the dataset ID (called 'did' in the table above).

# %%
dataset = datasets.get_dataset(1471)

print("This is dataset '%s', the target feature is called '%s'" % (dataset.name, dataset.default_target_attribute))
print("URL: %s" % dataset.url)
print(dataset.description[:500])
# Out:
# This is dataset 'eeg-eye-state', the target feature is called 'Class'
# URL: http://www.openml.org/data/download/1587924/phplE7q6h
# **Author**: Oliver Roesler, it12148'@'lehre.dhbw-stuttgart.de
# **Source**: [UCI](https://archive.ics.uci.edu/ml/datasets/EEG+Eye+State), Baden-Wuerttemberg, Cooperative State University (DHBW), Stuttgart, Germany
# **Please cite**:
#
# All data is from one continuous EEG measurement with the Emotiv EEG Neuroheadset. The duration of the measurement was 117 seconds. The eye state was detected via a camera during the EEG measurement and added later manually to the file after analysing the video fr

# %% [markdown]
# Get the actual data

# %%
X, y, attribute_names = dataset.get_data(target=dataset.default_target_attribute, return_attribute_names=True)
eeg = pd.DataFrame(X, columns=attribute_names)
eeg['class'] = y
print(eeg[:10])
# Out:
#             V1           V2           V3           V4           V5  \
# 0  4329.229980  4009.229980  4289.229980  4148.209961  4350.259766
# 1  4324.620117  4004.620117  4293.850098  4148.720215  4342.049805
# 2  4327.689941  4006.669922  4295.379883  4156.410156  4336.919922
# 3  4328.720215  4011.790039  4296.410156  4155.899902  4343.589844
# 4  4326.149902  4011.790039  4292.310059  4151.279785  4347.689941
# 5  4321.029785  4004.620117  4284.100098  4153.330078  4345.640137
# 6  4319.490234  4001.030029  4280.509766  4151.790039  4343.589844
# 7  4325.640137  4006.669922  4278.459961  4143.080078  4344.100098
# 8  4326.149902  4010.770020  4276.410156  4139.490234  4345.129883
# 9  4326.149902  4011.280029  4276.919922  4142.049805  4344.100098
#
#             V6           V7           V8           V9          V10  \
# 0  4586.149902  4096.919922  4641.029785  4222.049805  4238.459961
# 1  4586.669922  4097.439941  4638.970215  4210.770020  4226.669922
# 2  4583.589844  4096.919922  4630.259766  4207.689941  4222.049805
# 3  4582.560059  4097.439941  4630.770020  4217.439941  4235.379883
# 4  4586.669922  4095.899902  4627.689941  4210.770020  4244.100098
# 5  4587.180176  4093.330078  4616.919922  4202.560059  4232.819824
# 6  4584.620117  4089.739990  4615.899902  4212.310059  4226.669922
# 7  4583.080078  4087.179932  4614.870117  4205.640137  4230.259766
# 8  4584.100098  4091.280029  4608.209961  4187.689941  4229.740234
# 9  4582.560059  4092.820068  4608.720215  4194.359863  4228.720215
#
#            V11          V12          V13          V14  class
# 0  4211.279785  4280.509766  4635.899902  4393.850098      0
# 1  4207.689941  4279.490234  4632.819824  4384.100098      0
# 2  4206.669922  4282.049805  4628.720215  4389.229980      0
# 3  4210.770020  4287.689941  4632.310059  4396.410156      0
# 4  4212.819824  4288.209961  4632.819824  4398.459961      0
# 5  4209.740234  4281.029785  4628.209961  4389.740234      0
# 6  4201.029785  4269.740234  4625.129883  4378.459961      0
# 7  4195.899902  4266.669922  4622.049805  4380.509766      0
# 8  4202.049805  4273.850098  4627.180176  4389.740234      0
# 9  4212.819824  4277.950195  4637.439941  4393.330078      0

# %% [markdown]
# Train a scikit-learn model on the data

# %%
from sklearn import preprocessing, ensemble

dataset = datasets.get_dataset(61)
X, y = dataset.get_data(target=dataset.default_target_attribute)
clf = ensemble.RandomForestClassifier()
clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %% [markdown]
# You can also ask which features are categorical to do your own encoding

# %%
X, y, categorical = dataset.get_data(target=dataset.default_target_attribute,return_categorical_indicator=True)
enc = preprocessing.OneHotEncoder(categorical_features=categorical)
X = enc.fit_transform(X)
clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %% [markdown]
# # Tasks

# %% [markdown]
# To run benchmarks consistently (also across studies and tools), OpenML offers Tasks, which include specific train-test splits and other information.

# %% [markdown]
# ## List ALL the tasks

# %%
task_list = tasks.list_tasks(size=10)

mytasks = pd.DataFrame(task_list).transpose()
print("First 5 of %s tasks:" % len(mytasks))
#print(mytasks.columns)
print(mytasks[:5][['tid','did','name','task_type','estimation_procedure']])
# Out:
# First 5 of 10 tasks:
#   tid did        name                  task_type     estimation_procedure
# 1   1   1      anneal  Supervised Classification  10-fold Crossvalidation
# 2   2   2      anneal  Supervised Classification  10-fold Crossvalidation
# 3   3   3    kr-vs-kp  Supervised Classification  10-fold Crossvalidation
# 4   4   4       labor  Supervised Classification  10-fold Crossvalidation
# 5   5   5  arrhythmia  Supervised Classification  10-fold Crossvalidation

# %% [markdown]
# ## Download tasks

# %%
from pprint import pprint
task = tasks.get_task(10)
pprint(vars(task))
# Out:
# {'class_labels': ['normal', 'metastases', 'malign_lymph', 'fibrosis'],
#  'cost_matrix': None,
#  'dataset_id': 10,
#  'estimation_parameters': {'number_folds': '10',
#                            'number_repeats': '1',
#                            'percentage': '',
#                            'stratified_sampling': 'true'},
#  'estimation_procedure': {'data_splits_url': 'http://www.openml.org/api_splits/get/10/Task_10_splits.arff',
#                           'parameters': {'number_folds': '10',
#                                          'number_repeats': '1',
#                                          'percentage': '',
#                                          'stratified_sampling': 'true'},
#                           'type': 'crossvalidation'},
#  'evaluation_measure': 'predictive_accuracy',
#  'target_name': 'class',
#  'task_id': 10,
#  'task_type': 'Supervised Classification'}

# %% [markdown]
# # Runs

# %% [markdown]
# Run a scikit-learn classifier on the task (using the right splits)

# %%
from openml.runs import run_task

clf = ensemble.RandomForestClassifier()
run = run_task(task, clf)
print("RandomForest has run on the task.")
# Out:
# RandomForest has run on the task.

# %%
# %%capture
clf = ensemble.RandomForestClassifier()
run = run_task(task, clf)
return_code = run.publish()
print(return_code)

# %% [markdown]
# Upload the run to the OpenML server

# %%
# %%capture
import xmltodict

myrun = run.publish()

#if(return_code == 200):
#    response_dict = xmltodict.parse(response)
#    run_id = response_dict['oml:upload_run']['oml:run_id']
#    print("Uploaded run with id %s" % (run_id))
#    print("Check it at www.openml.org/r/%s" % (run_id))

# %% [markdown]
# ## OpenML with Python
# You can easily run and share scikit-learn experiments on OpenML

# %%
print(myrun.run_id)
# Out:
# 1843272

# %%
from sklearn import pipeline, ensemble, preprocessing
from openml import tasks,runs, datasets
task = tasks.get_task(59)
pipe = pipeline.Pipeline(steps=[
            ('Imputer', preprocessing.Imputer(strategy='median')),
            ('OneHotEncoder', preprocessing.OneHotEncoder(sparse=False, handle_unknown='ignore')),
            ('Classifier', ensemble.RandomForestClassifier())
           ])
run = runs.run_task(task, pipe)
#vars(run)
response = run.publish()
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <oml:run xmlns:oml="http://openml.org/openml">
# 	<oml:task_id>59</oml:task_id>
# 	<oml:flow_id>5432</oml:flow_id>
# 	<oml:parameter_setting>
# 		<oml:name>verbose</oml:name>
# 		<oml:value>0</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>min_samples_leaf</oml:name>
# 		<oml:value>1</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>class_weight</oml:name>
# 		<oml:value>None</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>bootstrap</oml:name>
# 		<oml:value>True</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>n_jobs</oml:name>
# 		<oml:value>1</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>oob_score</oml:name>
# 		<oml:value>False</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>n_estimators</oml:name>
# 		<oml:value>10</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>min_weight_fraction_leaf</oml:name>
# 		<oml:value>0.0</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>max_leaf_nodes</oml:name>
# 		<oml:value>None</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>warm_start</oml:name>
# 		<oml:value>False</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>min_impurity_split</oml:name>
# 		<oml:value>1e-07</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>max_depth</oml:name>
# 		<oml:value>None</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>max_features</oml:name>
# 		<oml:value>auto</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>criterion</oml:name>
# 		<oml:value>gini</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>min_samples_split</oml:name>
# 		<oml:value>2</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>random_state</oml:name>
# 		<oml:value>None</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>Classifier</oml:name>
# 		<oml:value>RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)</oml:value>
# 		<oml:component>5432</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>dtype</oml:name>
# 		<oml:value>&lt;class 'numpy.float64'&gt;</oml:value>
# 		<oml:component>4978</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>sparse</oml:name>
# 		<oml:value>False</oml:value>
# 		<oml:component>4978</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>n_values</oml:name>
# 		<oml:value>auto</oml:value>
# 		<oml:component>4978</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>categorical_features</oml:name>
# 		<oml:value>all</oml:value>
# 		<oml:component>4978</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>handle_unknown</oml:name>
# 		<oml:value>ignore</oml:value>
# 		<oml:component>4978</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>OneHotEncoder</oml:name>
# 		<oml:value>OneHotEncoder(categorical_features='all', dtype=&lt;class 'numpy.float64'&gt;,
#        handle_unknown='ignore', n_values='auto', sparse=False)</oml:value>
# 		<oml:component>5432</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>steps</oml:name>
# 		<oml:value>[('Imputer', Imputer(axis=0, copy=True, missing_values='NaN', strategy='median', verbose=0)), ('OneHotEncoder', OneHotEncoder(categorical_features='all', dtype=&lt;class 'numpy.float64'&gt;,
#        handle_unknown='ignore', n_values='auto', sparse=False)), ('Classifier', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False))]</oml:value>
# 		<oml:component>5432</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>copy</oml:name>
# 		<oml:value>True</oml:value>
# 		<oml:component>4977</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>verbose</oml:name>
# 		<oml:value>0</oml:value>
# 		<oml:component>4977</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>missing_values</oml:name>
# 		<oml:value>NaN</oml:value>
# 		<oml:component>4977</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>axis</oml:name>
# 		<oml:value>0</oml:value>
# 		<oml:component>4977</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>strategy</oml:name>
# 		<oml:value>median</oml:value>
# 		<oml:component>4977</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>Imputer</oml:name>
# 		<oml:value>Imputer(axis=0, copy=True, missing_values='NaN', strategy='median', verbose=0)</oml:value>
# 		<oml:component>5432</oml:component>
# 	</oml:parameter_setting>
# 	<oml:tag>Python_3.5.2.</oml:tag>
# 	<oml:tag>Sklearn_0.18.</oml:tag>
# 	<oml:tag>NumPy_1.11.2.</oml:tag>
# 	<oml:tag>SciPy_0.18.1.</oml:tag>
# 	<oml:tag>Thu_Dec__8_19.36.36_2016</oml:tag>
# 	<oml:tag>run_task</oml:tag>
# 	<oml:tag>sklearn.pipeline.Pipeline</oml:tag>
# </oml:run>
# ---------------------------------------------------------------------------
# OpenMLServerError                         Traceback (most recent call last)
# <ipython-input-36-6492af7e36b7> in <module>()
#       9 run = runs.run_task(task, pipe)
#      10 #vars(run)
# ---> 11 response = run.publish()
#
# /Users/joa/anaconda/lib/python3.5/site-packages/openml-0.3.0-py3.5.egg/openml/runs/run.py in publish(self)
#     147
#     148         return_code, return_value = _perform_api_call(
# --> 149             "/run/", file_elements=file_elements)
#     150         run_id = int(xmltodict.parse(return_value)['oml:upload_run']['oml:run_id'])
#     151         self.run_id = run_id
#
# /Users/joa/anaconda/lib/python3.5/site-packages/openml-0.3.0-py3.5.egg/openml/_api_calls.py in _perform_api_call(call, file_dictionary, file_elements, add_authentication)
#      42     if file_dictionary is not None or file_elements is not None:
#      43         return _read_url_files(url, file_dictionary=file_dictionary,
# ---> 44                                file_elements=file_elements)
#      45     return _read_url(url)
#      46
#
# /Users/joa/anaconda/lib/python3.5/site-packages/openml-0.3.0-py3.5.egg/openml/_api_calls.py in _read_url_files(url, file_dictionary, file_elements)
#      76     response = requests.post(url, data=data, files=file_elements)
#      77     if response.status_code != 200:
# ---> 78         raise OpenMLServerError(response.text)
#      79     if 'Content-Encoding' not in response.headers or \
#      80             response.headers['Content-Encoding'] != 'gzip':
#
# OpenMLServerError: OpenML Server error: <oml:error xmlns:oml="http://openml.org/openml">
# 	<oml:code>213</oml:code>
# 	<oml:message>Parameter in run xml unknown</oml:message>
# 		<oml:additional_information>Name: Classifier, flow id (component): 5432</oml:additional_information>
# 	</oml:error>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from sklearn import ensemble
from openml import tasks,runs
task = tasks.get_task(14951)
clf = ensemble.RandomForestClassifier()
run = runs.run_task(task, clf)
myrun = run.publish()
print(myrun.run_id)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <oml:run xmlns:oml="http://openml.org/openml">
# 	<oml:task_id>14951</oml:task_id>
# 	<oml:flow_id>4830</oml:flow_id>
# 	<oml:parameter_setting>
# 		<oml:name>verbose</oml:name>
# 		<oml:value>0</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>min_samples_leaf</oml:name>
# 		<oml:value>1</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>class_weight</oml:name>
# 		<oml:value>None</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>bootstrap</oml:name>
# 		<oml:value>True</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>n_jobs</oml:name>
# 		<oml:value>1</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>oob_score</oml:name>
# 		<oml:value>False</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>n_estimators</oml:name>
# 		<oml:value>10</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>min_weight_fraction_leaf</oml:name>
# 		<oml:value>0.0</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>max_leaf_nodes</oml:name>
# 		<oml:value>None</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>warm_start</oml:name>
# 		<oml:value>False</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>min_impurity_split</oml:name>
# 		<oml:value>1e-07</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>max_depth</oml:name>
# 		<oml:value>None</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>max_features</oml:name>
# 		<oml:value>auto</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>criterion</oml:name>
# 		<oml:value>gini</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>min_samples_split</oml:name>
# 		<oml:value>2</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:parameter_setting>
# 		<oml:name>random_state</oml:name>
# 		<oml:value>None</oml:value>
# 		<oml:component>4830</oml:component>
# 	</oml:parameter_setting>
# 	<oml:tag>Python_3.5.2.</oml:tag>
# 	<oml:tag>Sklearn_0.18.</oml:tag>
# 	<oml:tag>NumPy_1.11.2.</oml:tag>
# 	<oml:tag>SciPy_0.18.1.</oml:tag>
# 	<oml:tag>Thu_Dec__8_20.11.57_2016</oml:tag>
# 	<oml:tag>run_task</oml:tag>
# 	<oml:tag>sklearn.ensemble.forest.RandomForestClassifier</oml:tag>
# </oml:run>
# 1843273

# %%
print(myrun.detailed_evaluations)
# Out:
# None

# %%
myruns = runs.list_runs_by_task(59)
print(len(myruns))
print(myruns)
# Out:
# 2422
# [{'setup_id': 12, 'run_id': 81, 'uploader': 1, 'flow_id': 67, 'task_id': 59}, {'setup_id': 13, 'run_id': 161, 'uploader': 1, 'flow_id': 70, 'task_id': 59}, {'setup_id': 1, 'run_id': 234, 'uploader': 1, 'flow_id': 56, 'task_id': 59}, {'setup_id': 6, 'run_id': 447, 'uploader': 1, 'flow_id': 61, 'task_id': 59}, {'setup_id': 18, 'run_id': 473, 'uploader': 1, 'flow_id': 77, 'task_id': 59}, {'setup_id': 7, 'run_id': 491, 'uploader': 1, 'flow_id': 62, 'task_id': 59}, {'setup_id': 16, 'run_id': 550, 'uploader': 1, 'flow_id': 75, 'task_id': 59}, {'setup_id': 11, 'run_id': 6088, 'uploader': 2, 'flow_id': 66, 'task_id': 59}, {'setup_id': 12, 'run_id': 6157, 'uploader': 2, 'flow_id': 67, 'task_id': 59}, {'setup_id': 3, 'run_id': 6158, 'uploader': 2, 'flow_id': 58, 'task_id': 59}, {'setup_id': 47, 'run_id': 6159, 'uploader': 2, 'flow_id': 119, 'task_id': 59}, {'setup_id': 3, 'run_id': 6160, 'uploader': 2, 'flow_id': 58, 'task_id': 59}, {'setup_id': 47, 'run_id': 6161, 'uploader': 2, 'flow_id': 119, 'task_id': 59}, {'setup_id': 3, 'run_id': 6163, 'uploader': 2, 'flow_id': 58, 'task_id': 59}, {'setup_id': 47, 'run_id': 6164, 'uploader': 2, 'flow_id': 119, 'task_id': 59}, {'setup_id': 48, 'run_id': 6165, 'uploader': 2, 'flow_id': 120, 'task_id': 59}, {'setup_id': 49, 'run_id': 6166, 'uploader': 2, 'flow_id': 121, 'task_id': 59}, {'setup_id': 15, 'run_id': 6167, 'uploader': 2, 'flow_id': 74, 'task_id': 59}, {'setup_id': 50, 'run_id': 6168, 'uploader': 2, 'flow_id': 124, 'task_id': 59}, {'setup_id': 3, 'run_id': 6169, 'uploader': 2, 'flow_id': 58, 'task_id': 59}, {'setup_id': 47, 'run_id': 6170, 'uploader': 2, 'flow_id': 119, 'task_id': 59}, {'setup_id': 48, 'run_id': 6171, 'uploader': 2, 'flow_id': 120, 'task_id': 59}, {'setup_id': 49, 'run_id': 6172, 'uploader': 2, 'flow_id': 121, 'task_id': 59}, {'setup_id': 15, 'run_id': 6173, 'uploader': 2, 'flow_id': 74, 'task_id': 59}, {'setup_id': 50, 'run_id': 6174, 'uploader': 2, 'flow_id': 124, 'task_id': 59}, {'setup_id': 51, 'run_id': 6175, 'uploader': 2, 'flow_id': 126, 'task_id': 59}, {'setup_id': 13, 'run_id': 6176, 'uploader': 2, 'flow_id': 70, 'task_id': 59}, {'setup_id': 11, 'run_id': 6177, 'uploader': 2, 'flow_id': 66, 'task_id': 59}, {'setup_id': 52, 'run_id': 6178, 'uploader': 2, 'flow_id': 130, 'task_id': 59}, {'setup_id': 53, 'run_id': 6179, 'uploader': 2, 'flow_id': 131, 'task_id': 59}, {'setup_id': 16, 'run_id': 6180, 'uploader': 2, 'flow_id': 75, 'task_id': 59}, {'setup_id': 54, 'run_id': 6181, 'uploader': 2, 'flow_id': 133, 'task_id': 59}, {'setup_id': 17, 'run_id': 6182, 'uploader': 2, 'flow_id': 76, 'task_id': 59}, {'setup_id': 55, 'run_id': 6183, 'uploader': 2, 'flow_id': 136, 'task_id': 59}, {'setup_id': 3, 'run_id': 6184, 'uploader': 2, 'flow_id': 58, 'task_id': 59}, {'setup_id': 3, 'run_id': 6186, 'uploader': 2, 'flow_id': 58, 'task_id': 59}, {'setup_id': 47, 'run_id': 6187, 'uploader': 2, 'flow_id': 119, 'task_id': 59}, {'setup_id': 48, 'run_id': 6188, 'uploader': 2, 'flow_id': 120, 'task_id': 59}, {'setup_id': 49, 'run_id': 6189, 'uploader': 2, 'flow_id': 121, 'task_id': 59}, {'setup_id': 15, 'run_id': 6190, 'uploader': 2, 'flow_id': 74, 'task_id': 59}, {'setup_id': 50, 'run_id': 6191, 'uploader': 2, 'flow_id': 124, 'task_id': 59}, {'setup_id': 51, 'run_id': 6192, 'uploader': 2, 'flow_id': 126, 'task_id': 59}, {'setup_id': 13, 'run_id': 6193, 'uploader': 2, 'flow_id': 70, 'task_id': 59}, {'setup_id': 11, 'run_id': 6194, 'uploader': 2, 'flow_id': 66, 'task_id': 59}, {'setup_id': 52, 'run_id': 6195, 'uploader': 2, 'flow_id': 130, 'task_id': 59}, {'setup_id': 53, 'run_id': 6196, 'uploader': 2, 'flow_id': 131, 'task_id': 59}, {'setup_id': 16, 'run_id': 6197, 'uploader': 2, 'flow_id': 75, 'task_id': 59}, {'setup_id': 54, 'run_id': 6198, 'uploader': 2, 'flow_id': 133, 'task_id': 59}, {'setup_id': 17, 'run_id': 6199, 'uploader': 2, 'flow_id': 76, 'task_id': 59}, {'setup_id': 55, 'run_id': 6200, 'uploader': 2, 'flow_id': 136, 'task_id': 59}, {'setup_id': 56, 'run_id': 6201, 'uploader ...
